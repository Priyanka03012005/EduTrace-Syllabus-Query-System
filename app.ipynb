# %%
import pandas as pd

df = pd.read_csv('data.csv')  # Replace with your file name
df  # Display the full DataFrame in a notebook cell
# Out:
#                                      Course Title Column 0  \
# 0    System Programming and Compiler Construction        1
# 1    System Programming and Compiler Construction      NaN
# 2    System Programming and Compiler Construction      NaN
# 3    System Programming and Compiler Construction      NaN
# 4    System Programming and Compiler Construction      NaN
# ..                                            ...      ...
# 154                         Quantitative Analysis        2
# 155                         Quantitative Analysis        3
# 156                         Quantitative Analysis        4
# 157                         Quantitative Analysis        5
# 158                         Quantitative Analysis        6
#
#                                               Column 1  \
# 0                                                  NaN
# 1                                                  1.1
# 2                                                  NaN
# ...

# %%
num_columns = df.shape[1]
print("Total number of columns:", num_columns)
# Out:
# Total number of columns: 14

# %%
df = df.iloc[:, :6]  # Keep only the first 4 columns
df
# Out:
#                                      Course Title Column 0  \
# 0    System Programming and Compiler Construction        1
# 1    System Programming and Compiler Construction      NaN
# 2    System Programming and Compiler Construction      NaN
# 3    System Programming and Compiler Construction      NaN
# 4    System Programming and Compiler Construction      NaN
# ..                                            ...      ...
# 154                         Quantitative Analysis        2
# 155                         Quantitative Analysis        3
# 156                         Quantitative Analysis        4
# 157                         Quantitative Analysis        5
# 158                         Quantitative Analysis        6
#
#                                               Column 1  \
# 0                                                  NaN
# 1                                                  1.1
# 2                                                  NaN
# ...

# %%
import pandas as pd

# Read CSV file
df = pd.read_csv('data.csv')

# Keep only the first 6 columns (index 0 to 5)
df = df.iloc[:, :6]

# Display updated DataFrame
print(df.head())

# (Optional) Save the modified CSV
df.to_csv('data.csv', index=False)
# Out:
#                                    Course Title Column 0 Column 1  \
# 0  System Programming and Compiler Construction        1      NaN
# 1  System Programming and Compiler Construction      NaN      1.1
# 2  System Programming and Compiler Construction      NaN      NaN
# 3  System Programming and Compiler Construction      NaN      NaN
# 4  System Programming and Compiler Construction      NaN      NaN
#
#                                        Merged Column
# 0                    Introduction to System Software
# 1  Concept of System Software, Goals of system so...
# 2  and system programming, Introduction to variou...
# 3  as Assembler, Macro processor, Loader, Linker,...
# 4  Device Drivers, Operating system, Editors, Deb...

# %%
df.rename(columns={'Course Title': 'Subject', 'Column 0': 'Module no','Column 1': 'Module Sub no','Merged Column': 'Module content'}, inplace=True)
df = df.drop_duplicates(subset=['Subject', 'Module no'], keep='first')
df
# Out:
# C:\Users\gound\AppData\Local\Temp\ipykernel_8668\621409163.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'Course Title': 'Subject', 'Column 0': 'Module no','Column 1': 'Module Sub no','Merged Column': 'Module content'}, inplace=True)
#                                           Subject          Module no  \
# 0    System Programming and Compiler Construction                  1
# 1    System Programming and Compiler Construction                NaN
# 5    System Programming and Compiler Construction                  2
# 7    System Programming and Compiler Construction                  3
# 9    System Programming and Compiler Construction                  4
# 13   System Programming and Compiler Construction                  5
# ...

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('data.csv')  # Ensure 'data.csv' exists in the working directory

# Convert "Module no" to numeric (coerce errors to NaN)
df["Module no"] = pd.to_numeric(df["Module no"], errors="coerce")

# Identify the first occurrence and keep it, remove subsequent duplicates
df["is_duplicate"] = df.duplicated(subset=["Subject", "Module no"], keep="first")

# Keep only non-duplicate entries
df_filtered = df[df["is_duplicate"] == False].drop(columns=["is_duplicate"])

# Keep only the first 6 modules per subject
df_filtered = df_filtered[df_filtered["Module no"] <= 6]

# Save the cleaned data
df_filtered.to_csv('data.csv', index=False)

print("✅ Final cleaned data saved to data.csv")
df_filtered
# Out:
# ✅ Final cleaned data saved to data.csv
#                                          Subject  Module no  \
# 0   System Programming and Compiler Construction        1.0
# 1   System Programming and Compiler Construction        2.0
# 2   System Programming and Compiler Construction        3.0
# 3   System Programming and Compiler Construction        4.0
# 4   System Programming and Compiler Construction        5.0
# 5   System Programming and Compiler Construction        6.0
# 6                 Cryptography & System Security        1.0
# 7                 Cryptography & System Security        2.0
# 8                 Cryptography & System Security        3.0
# 9                 Cryptography & System Security        4.0
# 10                Cryptography & System Security        5.0
# 11                Cryptography & System Security        6.0
# 12                              Mobile Computing        1.0
# 13                              Mobile Computing        2.0
# ...

# %%
df = df.drop_duplicates(subset=['Subject', 'Module no'], keep='first')

# Display the updated DataFrame
print(df.head())
# Out:
#                                         Subject Module no Module Sub no  \
# 0  System Programming and Compiler Construction         1           NaN
# 1  System Programming and Compiler Construction       NaN           1.1
# 5  System Programming and Compiler Construction         2           NaN
# 7  System Programming and Compiler Construction         3           NaN
# 9  System Programming and Compiler Construction         4           NaN
#
#                                       Module content
# 0                    Introduction to System Software
# 1  Concept of System Software, Goals of system so...
# 5                                         Assemblers
# 7                         Macros and Macro Processor
# 9                                Loaders and Linkers

# %%
print("Hello")
# Out:
# Hello
